# %%
import xarray as xr
import matplotlib.pyplot as plt
import datetime as dt
import glob
import numpy as np
import cartopy.crs as ccrs
import metpy.calc as mpcalc
import metpy.units as units
from scipy.ndimage import uniform_filter
import wrf
import netCDF4 as nc
import tqdm
import pandas as pd

# %%
def latlon_dist(lat, lon, lats, lons):

        #Calculate great circle distance (Harversine) between a lat lon point (lat, lon) and a list of lat lon
        # points (lats, lons)
                        
        R = 6373.0
                        
        lat1 = np.deg2rad(lat)
        lon1 = np.deg2rad(lon)
        lat2 = np.deg2rad(lats)
        lon2 = np.deg2rad(lons)
                
        dlon = lon2 - lon1
        dlat = lat2 - lat1

        a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
        c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

        return (R * c)

def synoptic_diagnostics(domain, time):

    lon1, lat1, lon2, lat2 = domain

    #Calculate the 850 hPa wet bulb potential temperature gradient
    fq=xr.open_dataset(glob.glob("/g/data/rt52/era5/pressure-levels/reanalysis/q/"+time.strftime("%Y")+"/q_era5_oper_pl_"+time.strftime("%Y%m")+"*.nc")[0])\
                   .sel({"time":time.replace(minute=0), "level":slice(850,850)}).sel({"longitude":slice(lon1,lon2), "latitude":slice(lat2,lat1)}).metpy.assign_crs(grid_mapping_name='latitude_longitude').q#.metpy.parse_cf("q")
    ft=xr.open_dataset(glob.glob("/g/data/rt52/era5/pressure-levels/reanalysis/t/"+time.strftime("%Y")+"/t_era5_oper_pl_"+time.strftime("%Y%m")+"*.nc")[0])\
                   .sel({"time":time.replace(minute=0), "level":slice(850,850)}).sel({"longitude":slice(lon1,lon2), "latitude":slice(lat2,lat1)}).metpy.assign_crs(grid_mapping_name='latitude_longitude').t#.metpy.parse_cf("t")
    fdp = mpcalc.dewpoint_from_specific_humidity(850*units.units.hectopascal, ft, fq)

    p3d = xr.DataArray(data = np.ones(ft.shape) * 85000, coords=ft.coords, dims=ft.dims, attrs={"units":"Pa"})
    wb = wrf.wetbulb(p3d, ft, fq, meta=True)
    wb_pot = mpcalc.potential_temperature(p3d, wb).isel({"level":0})
#    dlat, dlon = mpcalc.gradient(wb_pot.rolling({"latitude":4, "longitude":4}).mean())
    dlat, dlon = mpcalc.gradient(wb_pot.coarsen({"latitude":4, "longitude":4},boundary="pad").mean())
    wb_pot_grad = np.sqrt(np.square(dlat) + np.square(dlon)).metpy.convert_units("K/km")

    #Calculate the 500 hPa geostrophic vorticity
    fz=xr.open_dataset(glob.glob("/g/data/rt52/era5/pressure-levels/reanalysis/z/"+time.strftime("%Y")+"/z_era5_oper_pl_"+time.strftime("%Y%m")+"*.nc")[0])\
                .sel({"time":time.replace(minute=0), "level":slice(500,500)})\
                .sel({"longitude":slice(lon1,lon2), "latitude":slice(lat2,lat1)})\
                .metpy.assign_crs(grid_mapping_name='latitude_longitude').z\
                .coarsen({"latitude":4, "longitude":4}, boundary="pad").mean().isel({"level":0})
                    #.rolling({"latitude":4, "longitude":4}).mean().isel({"level":0})
    lons, lats = np.meshgrid(fz.longitude, fz.latitude)
    f=mpcalc.coriolis_parameter(lats * units.units.degree)
    laplacian = np.abs(mpcalc.laplacian(fz) / f)
    
    return wb_pot_grad, laplacian

def get_point_data(f,lat,lon,r,plot=False,vmin=None,vmax=None):
    lats = f.coords.get("latitude").values
    lons = f.coords.get("longitude").values
    x,y = np.meshgrid(lons,lats)
    dist_km = (latlon_dist(lat, lon, y, x) )
    a,b = np.where( (dist_km <= r) )
    target_lons = xr.DataArray(lons[b],dims="points")
    target_lats = xr.DataArray(lats[a],dims="points")    
    f_slice = (f.sel(longitude=target_lons, latitude=target_lats))
    
    if plot:
        plt.figure()
        ax=plt.axes(projection=ccrs.PlateCarree())
        temp = np.where((dist_km <= r), f.values, np.nan)
        c=ax.pcolormesh(x,y,temp,vmin=vmin,vmax=vmax)
        plt.colorbar(c)
        ax.coastlines()
    
    return f_slice.values.max()

# %%
lon1 = 120; lat1 = -44.5; lon2 = 160; lat2 = -15
domain = [lon1,lat1,lon2,lat2]
r=500

details_list = [\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2006,9,24,1,41)], "rid":"2", "title":"a) Melbourne:  UTC"},\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2009,11,20,3,6)], "rid":"2", "title":"b) Melbourne:  UTC"},\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2010,3,6,3,30)], "rid":"2", "title":"c) Melbourne:  UTC"},\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2010,6,17,0,25)], "rid":"2", "title":"d) Melbourne:  UTC"},\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2011,11,18,7,4)], "rid":"2", "title":"e) Melbourne:  UTC"},\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2011,12,25,6,45)], "rid":"2", "title":"f) Melbourne:  UTC" },\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2012,2,26,9,11)], "rid":"2", "title":"g) Melbourne:  UTC"},\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2013,3,21,3,45)], "rid":"2", "title":"h) Melbourne: UTC" },\
        {"lat":-37.6654, "lon":144.8322, "time" : [dt.datetime(2015,2,28,9,25)], "rid":"2", "title":"i) Melbourne:  UTC"},\
       \
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2010,8,2,15,43)], "rid":"71", "title":"a) Sydney:  UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2012,8,10,4,21)], "rid":"71", "title":"b) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2013,2,23,13,43)], "rid":"71", "title":"c) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2014,10,14,11,39)], "rid":"71", "title":"d) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2015,3,1,4,34)], "rid":"71", "title":"e) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2015,12,16,2,3)], "rid":"71", "title":"f) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2016,1,14,4,20)], "rid":"71", "title":"g) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2016,6,4,3,42)], "rid":"71", "title":"h) Sydney: UTC"},\
        {"lat":-33.9465, "lon":151.1731, "time" : [dt.datetime(2017,4,9,8,3)], "rid":"71", "title":"i) Sydney: UTC"},\
       \
        {"lat":-27.6297, "lon":152.7111, "time" : [dt.datetime(2010,12,16,3,25)], "rid":"66", "title":"a) Amberley: UTC"},\
        {"lat":-27.6297, "lon":152.7111, "time" : [dt.datetime(2011,1,18,5,5)], "rid":"66", "title":"b) Amberley: UTC"},\
        {"lat":-27.4034, "lon":151.7413, "time" : [dt.datetime(2011,10,7,19,22)], "rid":"50", "title":"c) Oakey: UTC"},\
        {"lat":-27.4034, "lon":151.7413, "time" : [dt.datetime(2013,10,18,4,4)], "rid":"50", "title":"d) Oakey: UTC"},\
        {"lat":-27.6297, "lon":152.7111, "time" : [dt.datetime(2013,11,23,9,45)], "rid":"66", "title":"e) Amberley: UTC"},\
        {"lat":-27.4034, "lon":151.7413, "time" : [dt.datetime(2014,1,23,4,52)], "rid":"50", "title":"f) Oakey UTC"},\
        {"lat":-27.4034, "lon":151.7413, "time" : [dt.datetime(2016,1,29,4,22)], "rid":"50", "title":"g) Oakey UTC"},\
        {"lat":-27.6297, "lon":152.7111, "time" : [dt.datetime(2016,12,18,4,14)], "rid":"66", "title":"h) Amberley: UTC"},\
        {"lat":-27.4034, "lon":151.7413, "time" : [dt.datetime(2018,2,13,7,5)], "rid":"50", "title":"i) Oakey: UTC"},\
       \
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2007,10,27,9,3)], "rid":"27", "title":"a) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2008,12,9,6,18)], "rid":"27", "title":"b) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2010,12,7,9,27)], "rid":"27", "title":"c) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2011,11,8,9,47)], "rid":"27", "title":"d) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2012,1,29,4,42)], "rid":"27", "title":"e) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2012,11,30,8,33)], "rid":"27", "title":"f) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2014,10,31,7,52)], "rid":"27", "title":"g) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2015,12,7,11,20)], "rid":"27", "title":"h) "},\
        {"lat":-31.1558, "lon":136.8054, "time" : [dt.datetime(2017,12,18,11,30)], "rid":"27", "title":"i) "},\
         ]

import warnings
warnings.simplefilter("ignore")
rids = []
times = []
laplacians = []
wb_grads = []
lats = []
lons = []
for details in tqdm.tqdm(details_list):
    time = details["time"][0].replace(minute=0)
    wb_pot_grad, laplacian = synoptic_diagnostics(domain, time)
    laplacians.append(get_point_data(laplacian,details["lat"],details["lon"],r))
    wb_grads.append(get_point_data(wb_pot_grad,details["lat"],details["lon"],r))    
    times.append(time)
    rids.append(details["rid"])
    lats.append(details["lat"])
    lons.append(details["lon"])
df = pd.DataFrame({"rid":rids, "laplacian":laplacians, "wb_grad":wb_grads, "lat":lats, "lon":lons}, index=times)


#TODO: Consider coarsening the geopotential grid, before doing the Laplacian (rather than rolling mean)
#Incorperate time dimension and chunk for systematic application
# Out:
# 100%|██████████| 36/36 [00:05<00:00,  6.75it/s]

# %%
i=12

print(df.sort_values("wb_grad",ascending=False).iloc[i])
wb_pot_grad, laplacian = synoptic_diagnostics(domain, df.sort_values("wb_grad",ascending=False).index[i])
ax=plt.axes(projection=ccrs.PlateCarree())
wb_pot_grad.plot(ax=ax,vmin=0,vmax=0.05)
ax.coastlines()
get_point_data(wb_pot_grad,
               df.sort_values("wb_grad",ascending=False).iloc[i]["lat"],
               df.sort_values("wb_grad",ascending=False).iloc[i]["lon"],r,plot=True,vmin=0,vmax=0.05)

print(df.sort_values("laplacian",ascending=False).iloc[i])
plt.figure()
wb_pot_grad, laplacian = synoptic_diagnostics(domain, df.sort_values("laplacian",ascending=False).index[i])
ax=plt.axes(projection=ccrs.PlateCarree())
laplacian.plot(ax=ax,vmin=0,vmax=0.0005)
ax.coastlines()
get_point_data(laplacian,
               df.sort_values("laplacian",ascending=False).iloc[i]["lat"],
               df.sort_values("laplacian",ascending=False).iloc[i]["lon"],r,plot=True,vmin=0,vmax=0.0005)
# Out:
# rid                 2
# laplacian     0.00012
# wb_grad      0.038782
# lat          -37.6654
# lon          144.8322
# Name: 2010-03-06 03:00:00, dtype: object
# rid                71
# laplacian    0.000245
# wb_grad      0.037175
# lat          -33.9465
# lon          151.1731
# Name: 2013-02-23 13:00:00, dtype: object
# 0.0002452481991882497

# %%
df.plot(kind="scatter",x="laplacian",y="wb_grad")
# Out:
# <AxesSubplot:xlabel='laplacian', ylabel='wb_grad'>

# %%
import climtas.nci
climtas.nci.GadiClient()
# Out:
# <Client: 'tcp://127.0.0.1:36125' processes=1 threads=1, memory=64.00 GiB>

# %%
#Calculate the 850 hPa wet bulb potential temperature gradient
fq=xr.open_dataset(glob.glob("/g/data/rt52/era5/pressure-levels/reanalysis/q/"+time.strftime("%Y")+"/q_era5_oper_pl_"+time.strftime("%Y%m")+"*.nc")[0],chunks={"time":100})\
               .sel({"level":slice(850,850)}).sel({"longitude":slice(lon1,lon2), "latitude":slice(lat2,lat1)}).metpy.assign_crs(grid_mapping_name='latitude_longitude').q#.metpy.parse_cf("q")
ft=xr.open_dataset(glob.glob("/g/data/rt52/era5/pressure-levels/reanalysis/t/"+time.strftime("%Y")+"/t_era5_oper_pl_"+time.strftime("%Y%m")+"*.nc")[0],chunks={"time":100})\
               .sel({"level":slice(850,850)}).sel({"longitude":slice(lon1,lon2), "latitude":slice(lat2,lat1)}).metpy.assign_crs(grid_mapping_name='latitude_longitude').t#.metpy.parse_cf("t")
fdp = mpcalc.dewpoint_from_specific_humidity(850*units.units.hectopascal, ft, fq)

p3d = xr.DataArray(data = np.ones(ft.shape) * 85000, coords=ft.coords, dims=ft.dims, attrs={"units":"Pa"})
wb = wrf.wetbulb(p3d, ft, fq, meta=True)
wb_pot = mpcalc.potential_temperature(p3d, wb).isel({"level":0})
dlat, dlon = mpcalc.gradient(wb_pot.coarsen({"latitude":4, "longitude":4},boundary="pad").mean(),axes=["latitude","longitude"])
wb_pot_grad = np.sqrt(np.square(dlat) + np.square(dlon)).metpy.convert_units("K/km")
# Out:
# distributed.worker - ERROR - cannot pickle 'weakref' object
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3824, in dumps_function
#     result = cache_dumps[func]
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/utils.py", line 1366, in __getitem__
#     value = super().__getitem__(key)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/collections/__init__.py", line 1058, in __getitem__
#     raise KeyError(key)
# KeyError: <class 'pint.quantity.build_quantity_class.<locals>.Quantity'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 49, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
# AttributeError: Can't pickle local object 'build_quantity_class.<locals>.Quantity'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 2045, in transition_executing_done
#     self.send_task_state_to_scheduler(ts)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 2241, in send_task_state_to_scheduler
#     typ_serialized = dumps_function(typ)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3826, in dumps_function
#     result = pickle.dumps(func, protocol=4)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 60, in dumps
#     result = cloudpickle.dumps(x, **dump_kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
# TypeError: cannot pickle 'weakref' object
# distributed.worker - ERROR - Exception during execution of task array-original-0369ad718c23e56e35651490187d5df0.
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3824, in dumps_function
#     result = cache_dumps[func]
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/utils.py", line 1366, in __getitem__
#     value = super().__getitem__(key)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/collections/__init__.py", line 1058, in __getitem__
#     raise KeyError(key)
# KeyError: <class 'pint.quantity.build_quantity_class.<locals>.Quantity'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 49, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
# AttributeError: Can't pickle local object 'build_quantity_class.<locals>.Quantity'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3026, in execute
#     self.transition(ts, "memory", value=value)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 1749, in transition
#     state = func(ts, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 2045, in transition_executing_done
#     self.send_task_state_to_scheduler(ts)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 2241, in send_task_state_to_scheduler
#     typ_serialized = dumps_function(typ)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3826, in dumps_function
#     result = pickle.dumps(func, protocol=4)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 60, in dumps
#     result = cloudpickle.dumps(x, **dump_kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
# TypeError: cannot pickle 'weakref' object
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOLoop object at 0x1516ae56bdc0>>, <Task finished name='Task-49061' coro=<Worker.execute() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py:2935> exception=KeyError(('memory', 'error'))>)
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3824, in dumps_function
#     result = cache_dumps[func]
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/utils.py", line 1366, in __getitem__
#     value = super().__getitem__(key)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/collections/__init__.py", line 1058, in __getitem__
#     raise KeyError(key)
# KeyError: <class 'pint.quantity.build_quantity_class.<locals>.Quantity'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 49, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
# AttributeError: Can't pickle local object 'build_quantity_class.<locals>.Quantity'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3026, in execute
#     self.transition(ts, "memory", value=value)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 1749, in transition
#     state = func(ts, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 2045, in transition_executing_done
#     self.send_task_state_to_scheduler(ts)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 2241, in send_task_state_to_scheduler
#     typ_serialized = dumps_function(typ)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3826, in dumps_function
#     result = pickle.dumps(func, protocol=4)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/protocol/pickle.py", line 60, in dumps
#     result = cloudpickle.dumps(x, **dump_kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
# TypeError: cannot pickle 'weakref' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 3066, in execute
#     self.transition(ts, "error")
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/worker.py", line 1747, in transition
#     func = self._transitions[start, finish]
# KeyError: ('memory', 'error')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/ma/core.py in getdata(a, subok)
#     708     try:
# --> 709         data = a._data
#     710     except AttributeError:
#
# AttributeError: 'Array' object has no attribute '_data'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /jobfs/32071032.gadi-pbs/ipykernel_2167376/982652301.py in <module>
#       9 wb = wrf.wetbulb(p3d, ft, fq, meta=True)
#      10 wb_pot = mpcalc.potential_temperature(p3d, wb).isel({"level":0})
# ---> 11 dlat, dlon = mpcalc.gradient(wb_pot.coarsen({"latitude":4, "longitude":4},boundary="pad").mean(),axes=["latitude","longitude"])
#      12 wb_pot_grad = np.sqrt(np.square(dlat) + np.square(dlon)).metpy.convert_units("K/km")
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/metpy/calc/tools.py in gradient(f, axes, coordinates, deltas)
#    1193     """
#    1194     pos_kwarg, positions, axes = _process_gradient_args(f, axes, coordinates, deltas)
# -> 1195     return tuple(first_derivative(f, axis=axis, **{pos_kwarg: positions[ind]})
#    1196                  for ind, axis in enumerate(axes))
#    1197
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/metpy/calc/tools.py in <genexpr>(.0)
#    1193     """
#    1194     pos_kwarg, positions, axes = _process_gradient_args(f, axes, coordinates, deltas)
# -> 1195     return tuple(first_derivative(f, axis=axis, **{pos_kwarg: positions[ind]})
#    1196                  for ind, axis in enumerate(axes))
#    1197
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/metpy/calc/tools.py in wrapper(f, **kwargs)
#     947
#     948             # Calculate and return result as a DataArray
# --> 949             result = func(f.metpy.unit_array, **new_kwargs)
#     950             return xr.DataArray(result, coords=f.coords, dims=f.dims)
#     951         else:
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/metpy/calc/tools.py in first_derivative(f, axis, x, delta)
#    1047              + big_delta / (combined_delta * delta[delta_slice1]) * f[slice2])
#    1048
# -> 1049     return concatenate((left, center, right), axis=axis)
#    1050
#    1051
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/metpy/units.py in concatenate(arrs, axis)
#     135     # Use masked array concatenate to ensure masks are preserved, but convert to an
#     136     # array if there are no masked values.
# --> 137     data = np.ma.concatenate(data, axis=axis)
#     138     if not np.any(data.mask):
#     139         data = np.asarray(data)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/ma/core.py in concatenate(arrays, axis)
#    6965
#    6966     """
# -> 6967     d = np.concatenate([getdata(a) for a in arrays], axis)
#    6968     rcls = get_masked_subclass(*arrays)
#    6969     data = d.view(rcls)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/ma/core.py in <listcomp>(.0)
#    6965
#    6966     """
# -> 6967     d = np.concatenate([getdata(a) for a in arrays], axis)
#    6968     rcls = get_masked_subclass(*arrays)
#    6969     data = d.view(rcls)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/ma/core.py in getdata(a, subok)
#     709         data = a._data
#     710     except AttributeError:
# --> 711         data = np.array(a, copy=False, subok=subok)
#     712     if not subok:
#     713         return data.view(ndarray)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1489
#    1490     def __array__(self, dtype=None, **kwargs):
# -> 1491         x = self.compute()
#    1492         if dtype and x.dtype != dtype:
#    1493             x = x.astype(dtype)
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/dask/base.py in compute(self, **kwargs)
#     286         dask.base.compute
#     287         """
# --> 288         (result,) = compute(self, traverse=False, **kwargs)
#     289         return result
#     290
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/dask/base.py in compute(*args, **kwargs)
#     568         postcomputes.append(x.__dask_postcompute__())
#     569
# --> 570     results = schedule(dsk, keys, **kwargs)
#     571     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     572
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2687                     should_rejoin = False
#    2688             try:
# -> 2689                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2690             finally:
#    2691                 for f in futures.values():
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1964             else:
#    1965                 local_worker = None
# -> 1966             return self.sync(
#    1967                 self._gather,
#    1968                 futures,
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     858             return future
#     859         else:
# --> 860             return sync(
#     861                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     862             )
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     321     else:
#     322         while not e.is_set():
# --> 323             e.wait(10)
#     324     if error[0]:
#     325         typ, exc, tb = error[0]
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
wb_pot
# Out:
# <xarray.DataArray 'true_divide-80ced2b7c19af6032ca0f13ca1b5accb' (time: 744, latitude: 119, longitude: 161)>
# <Quantity(dask.array<getitem, shape=(744, 119, 161), dtype=float64, chunksize=(100, 119, 161), chunktype=numpy.ndarray>, 'kelvin')>
# Coordinates:
#   * time       (time) datetime64[ns] 2017-12-01 ... 2017-12-31T23:00:00
#     level      int64 850
#   * latitude   (latitude) float64 -15.0 -15.25 -15.5 ... -44.0 -44.25 -44.5
#   * longitude  (longitude) float64 120.0 120.2 120.5 120.8 ... 159.5 159.8 160.0
